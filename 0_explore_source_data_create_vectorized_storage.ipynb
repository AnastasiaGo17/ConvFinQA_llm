# %% [markdown]
# # Loading the data and checking availability
#
# Before starting this notebook, make sure you have done the following:
#
# 1. Get the file via wget and unzip it into the /data folder of your project
#  (I have put it one folder above the git project as I do not want to put it on my github)
#
# Commands in terminal:
#
#
# ```
# wget https://raw.githubusercontent.com/czyssrs/ConvFinQA/main/data.zip
# unzip data.zip -d /<your_path_to_data>
#
# ```
#
# 2. check that you have the jsons where you want them and check their size.
#
# Command in terminal (after navigating to the directory with the .json files):
#
#
#
# ```
# find . -type f -exec du -h {} + | sort -h
# ```

# %% [markdown]
# After a short celebration that the .train_json file that we need is not EXTREMELY large (41 M) we start looking at the data itself
#
# ![Screenshot 2024-12-04 at 20.18.13.png](data:image/png;base64,...)

# %% [markdown]
# # Data exploration

# %%
import os
import json

# %%
def load_json(json_path):
  """

  Args:
    json_path: string path to file to load
  """
  with open('json_path', 'r') as file:
    data = json.load(file)

# %%
os.getcwd()
# Out:
# '/content'

# %%
data_path = '../'

# %%
import
